# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 752

# %%
# Import requests library
import requests

# Import API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and datetime module from datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval      ")
print("------------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count += 1
        time.sleep(60)
    
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H:%M:%S")
        # Append the city information to city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp, 
                          "Humidity": city_humidity, 
                          "Cloudiness": city_clouds, 
                          "Wind Speed": city_wind,  
                          "Current Description": city_description})
    
    # If an error is experienced skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 1 | chara
# Processing Record 3 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 1 | kovrov
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | avera
# Processing Record 11 of Set 1 | pueblo nuevo
# Processing Record 12 of Set 1 | panjab
# Processing Record 13 of Set 1 | tarrafal
# Processing Record 14 of Set 1 | talcahuano
# Processing Record 15 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | cabo san lucas
# Processing Record 18 of Set 1 | kruisfontein
# Processing Record 19 of Set 1 | paamiut
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | bengkulu
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | upernavik
# Processing Record 27 of Set 1 | kodiak
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | port hardy
# Processing Record 31 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | sakakah
# Processing Record 35 of Set 1 | lumby
# Processing Record 36 of Set 1 | russell
# Processing Record 37 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | mitsamiouli
# Processing Record 40 of Set 1 | saint george
# Processing Record 41 of Set 1 | kunya
# Processing Record 42 of Set 1 | moose factory
# Processing Record 43 of Set 1 | bismarck
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | tuktoyaktuk
# Processing Record 46 of Set 1 | bantou
# Processing Record 47 of Set 1 | kemi
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | nikolskoye
# Processing Record 52 of Set 2 | georgetown
# Processing Record 53 of Set 2 | palmer
# Processing Record 54 of Set 2 | east london
# Processing Record 55 of Set 2 | port blair
# Processing Record 56 of Set 2 | kavieng
# Processing Record 57 of Set 2 | carahue
# Processing Record 58 of Set 2 | tiksi
# Processing Record 59 of Set 2 | arraial do cabo
# Processing Record 60 of Set 2 | la ronge
# Processing Record 61 of Set 2 | neiafu
# Processing Record 62 of Set 2 | severo-kurilsk
# Processing Record 63 of Set 2 | neath
# Processing Record 64 of Set 2 | vila
# Processing Record 65 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 66 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 67 of Set 2 | ampanihy
# Processing Record 68 of Set 2 | quatre cocos
# Processing Record 69 of Set 2 | patharia
# Processing Record 70 of Set 2 | passagem franca
# Processing Record 71 of Set 2 | chuy
# Processing Record 72 of Set 2 | airai
# Processing Record 73 of Set 2 | punta arenas
# Processing Record 74 of Set 2 | santa rosa
# Processing Record 75 of Set 2 | honiara
# Processing Record 76 of Set 2 | norman wells
# Processing Record 77 of Set 2 | manokwari
# Processing Record 78 of Set 2 | natal
# Processing Record 79 of Set 2 | mega
# Processing Record 80 of Set 2 | mandan
# Processing Record 81 of Set 2 | saldanha
# Processing Record 82 of Set 2 | carutapera
# Processing Record 83 of Set 2 | lompoc
# Processing Record 84 of Set 2 | atuona
# Processing Record 85 of Set 2 | sangar
# Processing Record 86 of Set 2 | los llanos de aridane
# Processing Record 87 of Set 2 | larreynaga
# Processing Record 88 of Set 2 | tuatapere
# Processing Record 89 of Set 2 | cape town
# Processing Record 90 of Set 2 | ravar
# Processing Record 91 of Set 2 | olafsvik
# Processing Record 92 of Set 2 | ancud
# Processing Record 93 of Set 2 | hobart
# Processing Record 94 of Set 2 | tasiilaq
# Processing Record 95 of Set 2 | arman
# Processing Record 96 of Set 2 | imbituba
# Processing Record 97 of Set 2 | fairbanks
# Processing Record 98 of Set 2 | bathsheba
# Processing Record 99 of Set 2 | bluff
# Processing Record 100 of Set 2 | nanortalik
# Processing Record 101 of Set 2 | salalah
# Processing Record 103 of Set 3 | talnakh
# Processing Record 104 of Set 3 | ulaanbaatar
# Processing Record 105 of Set 3 | te anau
# Processing Record 106 of Set 3 | provideniya
# Processing Record 107 of Set 3 | rocha
# Processing Record 108 of Set 3 | namibe
# Processing Record 109 of Set 3 | kapaa
# Processing Record 110 of Set 3 | veriora
# Processing Record 111 of Set 3 | saint-pierre
# Processing Record 112 of Set 3 | skjervoy
# Processing Record 113 of Set 3 | anyang
# Processing Record 114 of Set 3 | cockburn town
# Processing Record 115 of Set 3 | sola
# Processing Record 116 of Set 3 | faanui
# Processing Record 117 of Set 3 | gaziantep
# Processing Record 118 of Set 3 | ambilobe
# Processing Record 119 of Set 3 | lagoa
# Processing Record 120 of Set 3 | burgeo
# Processing Record 121 of Set 3 | souillac
# Processing Record 122 of Set 3 | lorengau
# Processing Record 123 of Set 3 | aklavik
# Processing Record 124 of Set 3 | asau
# Processing Record 125 of Set 3 | cerrito
# Processing Record 126 of Set 3 | tessalit
# Processing Record 127 of Set 3 | ayr
# Processing Record 128 of Set 3 | khatanga
# Processing Record 129 of Set 3 | monrovia
# Processing Record 130 of Set 3 | puerto ayora
# Processing Record 131 of Set 3 | comodoro rivadavia
# Processing Record 132 of Set 3 | lavrentiya
# Processing Record 133 of Set 3 | hithadhoo
# Processing Record 134 of Set 3 | funadhoo
# Processing Record 135 of Set 3 | ribeira grande
# Processing Record 136 of Set 3 | victoria
# Processing Record 137 of Set 3 | bambous virieux
# Processing Record 138 of Set 3 | lakatoro
# Processing Record 139 of Set 3 | vao
# Processing Record 140 of Set 3 | carnarvon
# Processing Record 141 of Set 3 | esperance
# Processing Record 142 of Set 3 | quelimane
# Processing Record 143 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 144 of Set 3 | tokmak
# Processing Record 145 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 146 of Set 3 | ilulissat
# Processing Record 147 of Set 3 | verkhnevilyuysk
# Processing Record 148 of Set 3 | coihaique
# Processing Record 149 of Set 3 | bonavista
# Processing Record 150 of Set 3 | nador
# Processing Record 151 of Set 3 | yellowknife
# Processing Record 152 of Set 3 | shibarghan
# City not found. Skipping...
# Processing Record 154 of Set 4 | hassleholm
# Processing Record 155 of Set 4 | fortuna
# Processing Record 156 of Set 4 | giaginskaya
# Processing Record 157 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 158 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 159 of Set 4 | chegdomyn
# Processing Record 160 of Set 4 | kjollefjord
# Processing Record 161 of Set 4 | pangkalanbuun
# Processing Record 162 of Set 4 | narsaq
# Processing Record 163 of Set 4 | medyn
# Processing Record 164 of Set 4 | noyabrsk
# Processing Record 165 of Set 4 | mogadishu
# Processing Record 166 of Set 4 | santa cruz de la palma
# Processing Record 167 of Set 4 | pogar
# Processing Record 168 of Set 4 | hilo
# Processing Record 169 of Set 4 | clyde river
# Processing Record 170 of Set 4 | guerrero negro
# Processing Record 171 of Set 4 | merrill
# Processing Record 172 of Set 4 | bolobo
# Processing Record 173 of Set 4 | villa union
# Processing Record 174 of Set 4 | caravelas
# Processing Record 175 of Set 4 | thompson
# Processing Record 176 of Set 4 | pacific grove
# Processing Record 177 of Set 4 | constitucion
# Processing Record 178 of Set 4 | tual
# Processing Record 179 of Set 4 | mahebourg
# Processing Record 180 of Set 4 | iqaluit
# Processing Record 181 of Set 4 | puerto escondido
# Processing Record 182 of Set 4 | pevek
# Processing Record 183 of Set 4 | zhigansk
# Processing Record 184 of Set 4 | dikson
# Processing Record 185 of Set 4 | beloha
# Processing Record 186 of Set 4 | mugreyevskiy
# City not found. Skipping...
# Processing Record 187 of Set 4 | kamaishi
# Processing Record 188 of Set 4 | walvis bay
# Processing Record 189 of Set 4 | havre-saint-pierre
# Processing Record 190 of Set 4 | pisco
# Processing Record 191 of Set 4 | sainte-thecle
# Processing Record 192 of Set 4 | baghdad
# Processing Record 193 of Set 4 | dukat
# Processing Record 194 of Set 4 | albina
# Processing Record 195 of Set 4 | sorland
# Processing Record 196 of Set 4 | deputatskiy
# Processing Record 197 of Set 4 | ardakan
# Processing Record 198 of Set 4 | biak
# Processing Record 199 of Set 4 | nkhotakota
# Processing Record 200 of Set 4 | xining
# Processing Record 201 of Set 4 | mount isa
# Processing Record 202 of Set 4 | surt
# Processing Record 203 of Set 4 | beyneu
# Processing Record 205 of Set 5 | kaitangata
# Processing Record 206 of Set 5 | sao filipe
# Processing Record 207 of Set 5 | bethel
# Processing Record 208 of Set 5 | nanning
# Processing Record 209 of Set 5 | guamal
# Processing Record 210 of Set 5 | presidente medici
# Processing Record 211 of Set 5 | waitati
# Processing Record 212 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 213 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 214 of Set 5 | mastic beach
# Processing Record 215 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 216 of Set 5 | katsuura
# Processing Record 217 of Set 5 | lucea
# Processing Record 218 of Set 5 | ranong
# Processing Record 219 of Set 5 | mildura
# Processing Record 220 of Set 5 | evensk
# Processing Record 221 of Set 5 | okmulgee
# Processing Record 222 of Set 5 | aksarka
# Processing Record 223 of Set 5 | yeletskiy
# City not found. Skipping...
# Processing Record 224 of Set 5 | xuanhua
# Processing Record 225 of Set 5 | maningrida
# Processing Record 226 of Set 5 | klaksvik
# Processing Record 227 of Set 5 | maniitsoq
# Processing Record 228 of Set 5 | ukiah
# Processing Record 229 of Set 5 | santa isabel do rio negro
# Processing Record 230 of Set 5 | san luis
# Processing Record 231 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 232 of Set 5 | port-gentil
# Processing Record 233 of Set 5 | ati
# Processing Record 234 of Set 5 | alta floresta
# Processing Record 235 of Set 5 | san patricio
# Processing Record 236 of Set 5 | baracoa
# Processing Record 237 of Set 5 | mweka
# Processing Record 238 of Set 5 | tocopilla
# Processing Record 239 of Set 5 | san sebastian
# Processing Record 240 of Set 5 | laguna
# Processing Record 241 of Set 5 | senhor do bonfim
# Processing Record 242 of Set 5 | tiznit
# Processing Record 243 of Set 5 | ponta do sol
# Processing Record 244 of Set 5 | saskylakh
# Processing Record 245 of Set 5 | zonguldak
# Processing Record 246 of Set 5 | riyadh
# Processing Record 247 of Set 5 | muros
# Processing Record 248 of Set 5 | nome
# Processing Record 249 of Set 5 | ulaangom
# Processing Record 250 of Set 5 | viedma
# Processing Record 251 of Set 5 | moba
# Processing Record 252 of Set 5 | itaituba
# Processing Record 253 of Set 5 | isangel
# Processing Record 254 of Set 5 | plettenberg bay
# Processing Record 256 of Set 6 | vardo
# Processing Record 257 of Set 6 | longyearbyen
# Processing Record 258 of Set 6 | severomorsk
# Processing Record 259 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 260 of Set 6 | troitskoye
# Processing Record 261 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 262 of Set 6 | khash
# Processing Record 263 of Set 6 | bongaree
# Processing Record 264 of Set 6 | jiangyou
# Processing Record 265 of Set 6 | havelock
# Processing Record 266 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 267 of Set 6 | vila velha
# Processing Record 268 of Set 6 | beira
# Processing Record 269 of Set 6 | carmo do rio claro
# Processing Record 270 of Set 6 | oistins
# Processing Record 271 of Set 6 | tazovskiy
# Processing Record 272 of Set 6 | ironton
# Processing Record 273 of Set 6 | shangrao
# Processing Record 274 of Set 6 | san quintin
# Processing Record 275 of Set 6 | san andres
# Processing Record 276 of Set 6 | moa
# Processing Record 277 of Set 6 | el pueblito
# Processing Record 278 of Set 6 | hambantota
# Processing Record 279 of Set 6 | katherine
# Processing Record 280 of Set 6 | korla
# Processing Record 281 of Set 6 | saurimo
# Processing Record 282 of Set 6 | sorong
# Processing Record 283 of Set 6 | cidreira
# Processing Record 284 of Set 6 | nemuro
# Processing Record 285 of Set 6 | castro alves
# Processing Record 286 of Set 6 | pemba
# Processing Record 287 of Set 6 | grand gaube
# Processing Record 288 of Set 6 | paka
# Processing Record 289 of Set 6 | plainview
# Processing Record 290 of Set 6 | kudahuvadhoo
# Processing Record 291 of Set 6 | vila franca do campo
# Processing Record 292 of Set 6 | mendi
# Processing Record 293 of Set 6 | grindavik
# Processing Record 294 of Set 6 | matsanga
# City not found. Skipping...
# Processing Record 295 of Set 6 | kytlym
# City not found. Skipping...
# Processing Record 296 of Set 6 | ornskoldsvik
# Processing Record 297 of Set 6 | nisia floresta
# Processing Record 298 of Set 6 | latur
# Processing Record 299 of Set 6 | saint-philippe
# Processing Record 300 of Set 6 | kirakira
# Processing Record 301 of Set 6 | beaufort
# Processing Record 302 of Set 6 | fort-shevchenko
# Processing Record 303 of Set 6 | abatskoye
# Processing Record 304 of Set 6 | lokosovo
# Processing Record 305 of Set 6 | hofn
# Processing Record 307 of Set 7 | charlottesville
# Processing Record 308 of Set 7 | kathmandu
# Processing Record 309 of Set 7 | marrakesh
# Processing Record 310 of Set 7 | kiunga
# Processing Record 311 of Set 7 | sozopol
# Processing Record 312 of Set 7 | jorochito
# Processing Record 313 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 314 of Set 7 | ambon
# Processing Record 315 of Set 7 | sulangan
# Processing Record 316 of Set 7 | namuac
# Processing Record 317 of Set 7 | warrington
# Processing Record 318 of Set 7 | bundaberg
# Processing Record 319 of Set 7 | lidice
# Processing Record 320 of Set 7 | high level
# Processing Record 321 of Set 7 | that phanom
# Processing Record 322 of Set 7 | ca mau
# Processing Record 323 of Set 7 | cocobeach
# Processing Record 324 of Set 7 | teahupoo
# Processing Record 325 of Set 7 | mattru
# Processing Record 326 of Set 7 | codrington
# Processing Record 327 of Set 7 | oranjestad
# Processing Record 328 of Set 7 | lebu
# Processing Record 329 of Set 7 | boa vista
# Processing Record 330 of Set 7 | erenhot
# Processing Record 331 of Set 7 | ratnagiri
# Processing Record 332 of Set 7 | marzuq
# Processing Record 333 of Set 7 | umea
# Processing Record 334 of Set 7 | qianguo
# Processing Record 335 of Set 7 | ust-kulom
# Processing Record 336 of Set 7 | yulara
# Processing Record 337 of Set 7 | harper
# Processing Record 338 of Set 7 | kungurtug
# Processing Record 339 of Set 7 | salinopolis
# Processing Record 340 of Set 7 | bilibino
# Processing Record 341 of Set 7 | chokurdakh
# Processing Record 342 of Set 7 | haines junction
# Processing Record 343 of Set 7 | colares
# Processing Record 344 of Set 7 | hailey
# Processing Record 345 of Set 7 | itarema
# Processing Record 346 of Set 7 | belaya gora
# Processing Record 347 of Set 7 | sawakin
# Processing Record 348 of Set 7 | aranjuez
# Processing Record 349 of Set 7 | marawi
# Processing Record 350 of Set 7 | tautira
# Processing Record 351 of Set 7 | labuhan
# Processing Record 352 of Set 7 | ketchikan
# Processing Record 353 of Set 7 | kieta
# Processing Record 354 of Set 7 | ixtapa
# Processing Record 355 of Set 7 | zhezkazgan
# Processing Record 356 of Set 7 | kabanjahe
# Processing Record 358 of Set 8 | san-pedro
# Processing Record 359 of Set 8 | meulaboh
# Processing Record 360 of Set 8 | srednekolymsk
# Processing Record 361 of Set 8 | babayurt
# Processing Record 362 of Set 8 | berdigestyakh
# Processing Record 363 of Set 8 | lata
# Processing Record 364 of Set 8 | shimoda
# Processing Record 365 of Set 8 | auki
# Processing Record 366 of Set 8 | laje
# Processing Record 367 of Set 8 | hasaki
# Processing Record 368 of Set 8 | marsassoum
# Processing Record 369 of Set 8 | nalut
# Processing Record 370 of Set 8 | naze
# Processing Record 371 of Set 8 | tiarei
# Processing Record 372 of Set 8 | mecca
# Processing Record 373 of Set 8 | flinders
# Processing Record 374 of Set 8 | selma
# Processing Record 375 of Set 8 | tlanchinol
# Processing Record 376 of Set 8 | miles city
# Processing Record 377 of Set 8 | leningradskiy
# Processing Record 378 of Set 8 | ostrovnoy
# Processing Record 379 of Set 8 | hamina
# Processing Record 380 of Set 8 | galveston
# Processing Record 381 of Set 8 | omboue
# Processing Record 382 of Set 8 | niksar
# Processing Record 383 of Set 8 | koppies
# Processing Record 384 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 385 of Set 8 | cherskiy
# Processing Record 386 of Set 8 | jacareacanga
# Processing Record 387 of Set 8 | pyapon
# Processing Record 388 of Set 8 | jejuri
# Processing Record 389 of Set 8 | pudozh
# Processing Record 390 of Set 8 | bruck an der mur
# Processing Record 391 of Set 8 | yar-sale
# Processing Record 392 of Set 8 | slonim
# Processing Record 393 of Set 8 | nizwa
# Processing Record 394 of Set 8 | san cristobal
# Processing Record 395 of Set 8 | houma
# Processing Record 396 of Set 8 | northam
# Processing Record 397 of Set 8 | okhotsk
# Processing Record 398 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 399 of Set 8 | banda aceh
# Processing Record 400 of Set 8 | manta
# Processing Record 401 of Set 8 | manzhouli
# Processing Record 402 of Set 8 | batagay-alyta
# Processing Record 403 of Set 8 | victor harbor
# Processing Record 404 of Set 8 | pierre
# Processing Record 405 of Set 8 | zaria
# Processing Record 406 of Set 8 | samarai
# Processing Record 407 of Set 8 | yerofey pavlovich
# Processing Record 409 of Set 9 | road town
# Processing Record 410 of Set 9 | amethi
# Processing Record 411 of Set 9 | vestmanna
# Processing Record 412 of Set 9 | alugan
# Processing Record 413 of Set 9 | mount gambier
# Processing Record 414 of Set 9 | sabalgarh
# Processing Record 415 of Set 9 | cuamba
# Processing Record 416 of Set 9 | faya
# Processing Record 417 of Set 9 | mehamn
# Processing Record 418 of Set 9 | amos
# Processing Record 419 of Set 9 | cabul-an
# Processing Record 420 of Set 9 | ahipara
# Processing Record 421 of Set 9 | poso
# Processing Record 422 of Set 9 | dingle
# Processing Record 423 of Set 9 | soe
# Processing Record 424 of Set 9 | goure
# Processing Record 425 of Set 9 | kjustendil
# Processing Record 426 of Set 9 | seymchan
# Processing Record 427 of Set 9 | salinas
# Processing Record 428 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 429 of Set 9 | kochetok
# Processing Record 430 of Set 9 | saint anthony
# Processing Record 431 of Set 9 | stokmarknes
# Processing Record 432 of Set 9 | shellbrook
# Processing Record 433 of Set 9 | iracoubo
# Processing Record 434 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 435 of Set 9 | ternate
# Processing Record 436 of Set 9 | iturama
# Processing Record 437 of Set 9 | poum
# Processing Record 438 of Set 9 | valparaiso
# Processing Record 439 of Set 9 | birjand
# Processing Record 440 of Set 9 | vanersborg
# Processing Record 441 of Set 9 | ivankiv
# Processing Record 442 of Set 9 | orodara
# Processing Record 443 of Set 9 | san jeronimo
# Processing Record 444 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 445 of Set 9 | tsabong
# Processing Record 446 of Set 9 | mpulungu
# Processing Record 447 of Set 9 | kismayo
# Processing Record 448 of Set 9 | nelson bay
# Processing Record 449 of Set 9 | kapit
# Processing Record 450 of Set 9 | twin falls
# Processing Record 451 of Set 9 | kyra
# Processing Record 452 of Set 9 | maumelle
# Processing Record 453 of Set 9 | kutum
# Processing Record 454 of Set 9 | acapulco
# Processing Record 455 of Set 9 | yinchuan
# Processing Record 456 of Set 9 | buin
# Processing Record 457 of Set 9 | makakilo city
# Processing Record 458 of Set 9 | havoysund
# Processing Record 460 of Set 10 | nishihara
# Processing Record 461 of Set 10 | general roca
# Processing Record 462 of Set 10 | carauari
# Processing Record 463 of Set 10 | xingyi
# Processing Record 464 of Set 10 | fairview
# Processing Record 465 of Set 10 | baruun-urt
# Processing Record 466 of Set 10 | kununurra
# Processing Record 467 of Set 10 | tukrah
# Processing Record 468 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 469 of Set 10 | mamallapuram
# Processing Record 470 of Set 10 | camacha
# Processing Record 471 of Set 10 | sampit
# Processing Record 472 of Set 10 | acarau
# Processing Record 473 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 474 of Set 10 | tilichiki
# Processing Record 475 of Set 10 | trelew
# Processing Record 476 of Set 10 | elizabeth city
# Processing Record 477 of Set 10 | hauterive
# Processing Record 478 of Set 10 | anadyr
# Processing Record 479 of Set 10 | abramovka
# Processing Record 480 of Set 10 | najran
# Processing Record 481 of Set 10 | bada
# Processing Record 482 of Set 10 | villa carlos paz
# Processing Record 483 of Set 10 | ugento
# Processing Record 484 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 485 of Set 10 | komsomolskiy
# Processing Record 486 of Set 10 | abha
# Processing Record 487 of Set 10 | hudiksvall
# Processing Record 488 of Set 10 | aktash
# Processing Record 489 of Set 10 | olga
# Processing Record 490 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 491 of Set 10 | nioro
# Processing Record 492 of Set 10 | linchuan
# City not found. Skipping...
# Processing Record 493 of Set 10 | trincomalee
# Processing Record 494 of Set 10 | dongying
# Processing Record 495 of Set 10 | el dovio
# Processing Record 496 of Set 10 | pinawa
# Processing Record 497 of Set 10 | sawtell
# Processing Record 498 of Set 10 | kribi
# Processing Record 499 of Set 10 | bandarbeyla
# Processing Record 500 of Set 10 | barra patuca
# Processing Record 501 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 502 of Set 10 | inyonga
# Processing Record 503 of Set 10 | khandyga
# Processing Record 504 of Set 10 | abnub
# Processing Record 505 of Set 10 | pangnirtung
# Processing Record 506 of Set 10 | lichinga
# Processing Record 507 of Set 10 | nantucket
# Processing Record 508 of Set 10 | hami
# Processing Record 509 of Set 10 | sabha
# Processing Record 511 of Set 11 | shenjiamen
# Processing Record 512 of Set 11 | beisfjord
# Processing Record 513 of Set 11 | xinan
# Processing Record 514 of Set 11 | castro daire
# Processing Record 515 of Set 11 | turayf
# Processing Record 516 of Set 11 | caraballeda
# Processing Record 517 of Set 11 | hit
# Processing Record 518 of Set 11 | kavaratti
# Processing Record 519 of Set 11 | linxi
# Processing Record 520 of Set 11 | lasa
# Processing Record 521 of Set 11 | kiama
# Processing Record 522 of Set 11 | hebertville
# City not found. Skipping...
# Processing Record 523 of Set 11 | akdepe
# Processing Record 524 of Set 11 | ondjiva
# Processing Record 525 of Set 11 | vestmannaeyjar
# Processing Record 526 of Set 11 | pacifica
# Processing Record 527 of Set 11 | cuenca
# Processing Record 528 of Set 11 | barcelona
# Processing Record 529 of Set 11 | nouadhibou
# Processing Record 530 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 531 of Set 11 | tsiroanomandidy
# Processing Record 532 of Set 11 | iquitos
# Processing Record 533 of Set 11 | kajaani
# Processing Record 534 of Set 11 | sibu
# Processing Record 535 of Set 11 | cap-aux-meules
# Processing Record 536 of Set 11 | venado tuerto
# Processing Record 537 of Set 11 | oriximina
# Processing Record 538 of Set 11 | youghal
# Processing Record 539 of Set 11 | karhal
# Processing Record 540 of Set 11 | chifeng
# Processing Record 541 of Set 11 | chietla
# Processing Record 542 of Set 11 | colac
# Processing Record 543 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 544 of Set 11 | verkhnyaya inta
# Processing Record 545 of Set 11 | turbat
# Processing Record 546 of Set 11 | yabrud
# Processing Record 547 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 548 of Set 11 | pemangkat
# Processing Record 549 of Set 11 | senneterre
# Processing Record 550 of Set 11 | ciudad bolivar
# Processing Record 551 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 552 of Set 11 | ust-kuyga
# Processing Record 553 of Set 11 | tura
# Processing Record 554 of Set 11 | immenstadt
# Processing Record 555 of Set 11 | lloydminster
# Processing Record 556 of Set 11 | kargopol
# Processing Record 557 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 558 of Set 11 | nanakuli
# Processing Record 559 of Set 11 | port macquarie
# Processing Record 560 of Set 11 | piopio
# Processing Record 562 of Set 12 | cruzeiro do sul
# Processing Record 563 of Set 12 | pathein
# Processing Record 564 of Set 12 | balkhash
# Processing Record 565 of Set 12 | idrinskoye
# Processing Record 566 of Set 12 | glendive
# Processing Record 567 of Set 12 | sinnamary
# Processing Record 568 of Set 12 | manggar
# Processing Record 569 of Set 12 | gat
# Processing Record 570 of Set 12 | mayo
# Processing Record 571 of Set 12 | torbay
# Processing Record 572 of Set 12 | moyale
# Processing Record 573 of Set 12 | chumikan
# Processing Record 574 of Set 12 | los algarrobos
# Processing Record 575 of Set 12 | marsa matruh
# Processing Record 576 of Set 12 | mamit
# Processing Record 577 of Set 12 | praia da vitoria
# Processing Record 578 of Set 12 | sao jose da coroa grande
# Processing Record 579 of Set 12 | manaus
# Processing Record 580 of Set 12 | goderich
# Processing Record 581 of Set 12 | tuni
# Processing Record 582 of Set 12 | zumpahuacan
# Processing Record 583 of Set 12 | tlaltenango
# Processing Record 584 of Set 12 | letlhakeng
# Processing Record 585 of Set 12 | pergamino
# Processing Record 586 of Set 12 | port lincoln
# Processing Record 587 of Set 12 | play cu
# City not found. Skipping...
# Processing Record 588 of Set 12 | alingsas
# Processing Record 589 of Set 12 | antofagasta
# Processing Record 590 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 591 of Set 12 | san carlos del zulia
# Processing Record 592 of Set 12 | kasra
# City not found. Skipping...
# Processing Record 593 of Set 12 | ban nahin
# Processing Record 594 of Set 12 | minas
# Processing Record 595 of Set 12 | geraldton
# Processing Record 596 of Set 12 | fereydun kenar
# Processing Record 597 of Set 12 | kahului
# Processing Record 598 of Set 12 | svetlogorsk
# Processing Record 599 of Set 12 | miragoane
# Processing Record 600 of Set 12 | waingapu
# Processing Record 601 of Set 12 | moses lake
# Processing Record 602 of Set 12 | hanmer springs
# Processing Record 603 of Set 12 | gladstone
# Processing Record 604 of Set 12 | gleisdorf
# Processing Record 605 of Set 12 | sachin
# Processing Record 606 of Set 12 | wasilla
# Processing Record 607 of Set 12 | banjarmasin
# Processing Record 608 of Set 12 | sao joaquim
# Processing Record 609 of Set 12 | drayton valley
# Processing Record 610 of Set 12 | muli
# Processing Record 611 of Set 12 | mollendo
# Processing Record 613 of Set 13 | kalmunai
# Processing Record 614 of Set 13 | hastings
# Processing Record 615 of Set 13 | husavik
# Processing Record 616 of Set 13 | denpasar
# Processing Record 617 of Set 13 | swan hill
# Processing Record 618 of Set 13 | lodja
# Processing Record 619 of Set 13 | yelizovo
# Processing Record 620 of Set 13 | warrnambool
# Processing Record 621 of Set 13 | coahuayana
# Processing Record 622 of Set 13 | blyth
# Processing Record 623 of Set 13 | alnashi
# Processing Record 624 of Set 13 | alekseyevsk
# Processing Record 625 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 626 of Set 13 | bat yam
# Processing Record 627 of Set 13 | kampene
# Processing Record 628 of Set 13 | watertown
# Processing Record 629 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 630 of Set 13 | charters towers
# Processing Record 631 of Set 13 | biltine
# Processing Record 632 of Set 13 | la victoria
# Processing Record 633 of Set 13 | gewane
# Processing Record 634 of Set 13 | aitape
# Processing Record 635 of Set 13 | onguday
# Processing Record 636 of Set 13 | dicabisagan
# Processing Record 637 of Set 13 | mangrol
# Processing Record 638 of Set 13 | andenes
# Processing Record 639 of Set 13 | isla vista
# Processing Record 640 of Set 13 | southbridge
# Processing Record 641 of Set 13 | yerbogachen
# Processing Record 642 of Set 13 | kem
# Processing Record 643 of Set 13 | broken hill
# Processing Record 644 of Set 13 | oskarshamn
# Processing Record 645 of Set 13 | amapa
# Processing Record 646 of Set 13 | coolum beach
# Processing Record 647 of Set 13 | kamenka
# Processing Record 648 of Set 13 | college
# Processing Record 649 of Set 13 | roald
# Processing Record 650 of Set 13 | jasper
# Processing Record 651 of Set 13 | lewistown
# Processing Record 652 of Set 13 | diamantino
# Processing Record 653 of Set 13 | ponta delgada
# Processing Record 654 of Set 13 | zuienkerke
# Processing Record 655 of Set 13 | ust-tsilma
# Processing Record 656 of Set 13 | the pas
# Processing Record 657 of Set 13 | zhangye
# Processing Record 658 of Set 13 | kansk
# Processing Record 659 of Set 13 | fort nelson
# Processing Record 660 of Set 13 | bani walid
# Processing Record 661 of Set 13 | shubarshi
# Processing Record 662 of Set 13 | kaduqli
# Processing Record 664 of Set 14 | deniliquin
# Processing Record 665 of Set 14 | la raya de santa maria
# Processing Record 666 of Set 14 | katangli
# Processing Record 667 of Set 14 | meadow lake
# Processing Record 668 of Set 14 | hirara
# Processing Record 669 of Set 14 | aranos
# Processing Record 670 of Set 14 | ahuimanu
# Processing Record 671 of Set 14 | lichuan
# Processing Record 672 of Set 14 | sambava
# Processing Record 673 of Set 14 | presidencia roque saenz pena
# Processing Record 674 of Set 14 | margate
# Processing Record 675 of Set 14 | daska
# Processing Record 676 of Set 14 | kulhudhuffushi
# Processing Record 677 of Set 14 | kiruna
# Processing Record 678 of Set 14 | umm kaddadah
# Processing Record 679 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 680 of Set 14 | pijijiapan
# Processing Record 681 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 682 of Set 14 | brus laguna
# Processing Record 683 of Set 14 | broome
# Processing Record 684 of Set 14 | luanda
# Processing Record 685 of Set 14 | bulgan
# Processing Record 686 of Set 14 | vung tau
# Processing Record 687 of Set 14 | berlevag
# Processing Record 688 of Set 14 | sitka
# Processing Record 689 of Set 14 | sivas
# Processing Record 690 of Set 14 | madison
# Processing Record 691 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 692 of Set 14 | tsimlyansk
# Processing Record 693 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 694 of Set 14 | peniche
# Processing Record 695 of Set 14 | kalaleh
# Processing Record 696 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 697 of Set 14 | alice springs
# Processing Record 698 of Set 14 | kaohsiung
# Processing Record 699 of Set 14 | birobidzhan
# Processing Record 700 of Set 14 | cusco
# Processing Record 701 of Set 14 | ustynivka
# Processing Record 702 of Set 14 | morales
# Processing Record 703 of Set 14 | atyrau
# Processing Record 704 of Set 14 | celestun
# Processing Record 705 of Set 14 | cabedelo
# Processing Record 706 of Set 14 | panguipulli
# Processing Record 707 of Set 14 | hare bay
# Processing Record 708 of Set 14 | ankpa
# Processing Record 709 of Set 14 | vostok
# Processing Record 710 of Set 14 | rawson
# Processing Record 711 of Set 14 | tutoia
# Processing Record 712 of Set 14 | kaputa
# Processing Record 713 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 715 of Set 15 | ureki
# Processing Record 716 of Set 15 | kaoma
# Processing Record 717 of Set 15 | xiongshi
# City not found. Skipping...
# Processing Record 718 of Set 15 | phan thiet
# Processing Record 719 of Set 15 | qasigiannguit
# Processing Record 720 of Set 15 | gombe
# Processing Record 721 of Set 15 | itaueira
# Processing Record 722 of Set 15 | la sarre
# Processing Record 723 of Set 15 | san carlos de bariloche
# Processing Record 724 of Set 15 | tavatuy
# Processing Record 725 of Set 15 | hoi an
# Processing Record 726 of Set 15 | la rioja
# Processing Record 727 of Set 15 | aripuana
# Processing Record 728 of Set 15 | ormara
# Processing Record 729 of Set 15 | trairi
# Processing Record 730 of Set 15 | birao
# Processing Record 731 of Set 15 | nelidovo
# Processing Record 732 of Set 15 | suruc
# Processing Record 733 of Set 15 | mao
# Processing Record 734 of Set 15 | khandbari
# Processing Record 735 of Set 15 | manali
# Processing Record 736 of Set 15 | techiman
# Processing Record 737 of Set 15 | macklin
# Processing Record 738 of Set 15 | taoudenni
# Processing Record 739 of Set 15 | port hedland
# Processing Record 740 of Set 15 | port hawkesbury
# Processing Record 741 of Set 15 | daitari
# Processing Record 742 of Set 15 | nadym
# Processing Record 743 of Set 15 | beringovskiy
# Processing Record 744 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 745 of Set 15 | prainha
# Processing Record 746 of Set 15 | tungor
# Processing Record 747 of Set 15 | forest hill
# Processing Record 748 of Set 15 | coquimbo
# Processing Record 749 of Set 15 | tera
# Processing Record 750 of Set 15 | ponnani
# Processing Record 751 of Set 15 | mabaruma
# Processing Record 752 of Set 15 | malangali
# Processing Record 753 of Set 15 | shaunavon
# Processing Record 754 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 755 of Set 15 | nanlong
# Processing Record 756 of Set 15 | loralai
# Processing Record 757 of Set 15 | porto walter
# Processing Record 758 of Set 15 | kangaatsiaq
# Processing Record 759 of Set 15 | aswan
# Processing Record 760 of Set 15 | anaco
# Processing Record 761 of Set 15 | blagoyevo
# Processing Record 762 of Set 15 | taltal
# Processing Record 763 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 764 of Set 15 | guthrie
# Processing Record 766 of Set 16 | whyalla
# Processing Record 767 of Set 16 | rassvet
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Chara      RU  56.9064  118.2631     52.56        97         100
# 1     Kovrov      RU  56.3572   41.3192     59.11        97         100
# 2    Rikitea      PF -23.1203 -134.9692     73.67        80          16
# 3  Busselton      AU -33.6500  115.3333     56.57        63          87
# 4     Albany      US  42.6001  -73.9662     72.25        62           4
#
#    Wind Speed Current Description
# 0        1.70       moderate rain
# 1        3.58     overcast clouds
# 2       12.06       moderate rain
# 3       14.61     overcast clouds
# 4        4.50           clear sky

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the city_data into CSV
city_data_df.to_csv(output_data_file, index_label = "City_ID")
